# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator

plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman']
plt.rcParams['font.size'] = 10

methods = ['ARoG', 'with R-all', 'with E-default']


WebQSP = np.array([
    [74.7, 58.9],
    [74.3, 59.6],
    [71.6, 52.7]
])
CWQ = np.array([
    [60.0, 36.3],
    [58.6, 34.5],
    [54.5, 30.1]
])
GrailQA = np.array([
    [78.7, 71.8],
    [78.4, 71.8],
    [75.2, 68.0]
])
data_list = [WebQSP, CWQ, GrailQA]


color_list = ["#B6DDF6", "#FFF3C2", "#D6ECCB"]
edgecolor_list = ["#6BAED6", "#FFD966", "#9ACBA0"]
hatch_list = [None, None, None]

bar_width = 0.25
x = np.arange(2)
gap = 0.04

fig, axs = plt.subplots(1, 3, figsize=(6, 2), dpi=400, sharey=False)
all_titles = [
    "(a) WebQSP",
    "(b) CWQ",
    "(c) GrailQA"
]
ylim_list = [80, 65, 80]
ylim_list_bottom = [55, 25, 70]
yticks_list = [np.arange(50, 80, 5),
               np.arange(25, 65, 5),
               np.arange(65, 80, 2.5)]

bar_lists = []
for idx, ax in enumerate(axs):
    data = data_list[idx]

    bar_list = []
    for method_i in range(len(methods)):
        bars = ax.bar(x + (method_i - 1) * bar_width, data[method_i],
                      width=bar_width - gap,
                      label=methods[method_i],
                      color=color_list[method_i],
                      edgecolor=edgecolor_list[method_i],
                      linewidth=0.9,
                      hatch=hatch_list[method_i] if hatch_list[method_i] else '',
                      zorder=3)
        bar_list.append(bars)

    bar_lists.append(bar_list)

    ax.set_ylim(ylim_list_bottom[idx], ylim_list[idx])
    ax.set_yticks(yticks_list[idx])
    ax.grid(axis='y', linestyle=':', linewidth=1, alpha=0.5, zorder=0)
    ax.set_axisbelow(True)
    ax.set_xticks(x)
    ax.set_xticklabels(["#Total", "#Filter"], rotation=0, ha='center')
    ax.set_xlabel(all_titles[idx], fontsize=10, labelpad=3, ha='center')

    if idx == 0:
        ax.set_ylabel("Hits@1", labelpad=2, fontsize=10)
    else:
        ax.set_ylabel("")
    for spine in ax.spines.values():
        spine.set_linewidth(0.7)
    ax.tick_params(axis='y', labelsize=10)

handles = [bar[0] for bar in bar_lists[0]]
fig.legend(handles, methods, loc='upper center',
           bbox_to_anchor=(0.5, 1.0),
           ncol=3, frameon=False, fontsize=10,
           columnspacing=0.8, handletextpad=0.4)

plt.tight_layout(pad=0.8, rect=[0, 0, 1, 0.9])
plt.subplots_adjust(hspace=0.6, wspace=0.3)
plt.savefig('1.pdf', format='pdf', dpi=400, transparent=True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator

plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman']
plt.rcParams['font.size'] = 10

methods = ['ARoG', 'with CoT', 'with Dec', 'w/o SA']


webqsp = np.array([
    [74.7, 58.9],  # ARoG
    [72.3, 57.9],  # with CoT
    [69.6, 56.3],  # with Dec
    [68.1, 56.8]   # w/o SA
])
cwq = np.array([
    [60.0, 36.3],  # ARoG
    [58.3, 34.1],  # with CoT
    [52.2, 33.2],  # with Dec
    [50.3, 30.5],  # w/o SA
])
grailqa = np.array([
    [78.7, 71.8],  # ARoG
    [78.2, 70.6],  # with CoT
    [77.8, 70.7],  # with Dec
    [76.3, 70.7]   # w/o SA
])

data_list = [webqsp, cwq, grailqa]

color_list = ["#B6DDF6", "#D2EAFB", "#FFF3C2", "#FFE8B6"]
edgecolor_list = ["#6BAED6", "#4292C6", "#FFD966", "#FFC000"]
hatch_list = [None, "//", None, "//"]

bar_width = 0.22
x = np.arange(2)
gap = 0.04

fig, axs = plt.subplots(1, 3, figsize=(6, 2), dpi=400, sharey=False)
all_titles = [
    "(a) WebQSP",
    "(b) CWQ",
    "(c) GrailQA"
]
ylim_list = [80, 65, 80]
ylim_list_bottom = [55, 25, 70]
yticks_list = [np.arange(50, 80, 5),
               np.arange(25, 65, 5),
               np.arange(70, 80, 2.5)]

bar_lists = []
for idx, ax in enumerate(axs):
    data = data_list[idx]

    bar_list = []
    for method_i in range(len(methods)):
        bars = ax.bar(x + (method_i - 1.5) * bar_width, data[method_i],
                      width=bar_width - gap,
                      label=methods[method_i],
                      color=color_list[method_i],
                      edgecolor=edgecolor_list[method_i],
                      linewidth=0.9,
                      hatch=hatch_list[method_i] if hatch_list[method_i] else '',
                      zorder=3)
        bar_list.append(bars)

    bar_lists.append(bar_list)

    ax.set_ylim(ylim_list_bottom[idx], ylim_list[idx])
    ax.set_yticks(yticks_list[idx])
    # if idx == 0 or idx == 1:
    #     ax.yaxis.set_major_locator(MultipleLocator(5))
    ax.grid(axis='y', linestyle=':', linewidth=1, alpha=0.5, zorder=0)
    ax.set_axisbelow(True)
    ax.set_xticks(x)
    ax.set_xticklabels(["#Total", "#Filtered"], rotation=0, ha='center')
    ax.set_xlabel(all_titles[idx], fontsize=10, labelpad=3, ha='center')

    if idx == 0:
    # if idx == 0:
        ax.set_ylabel("Hits@1", labelpad=2, fontsize=10)
    else:
        ax.set_ylabel("")
        # ax.set_yticklabels([])
        # ax.tick_params(labelleft=False)

    for spine in ax.spines.values():
        spine.set_linewidth(0.7)
    ax.tick_params(axis='y', labelsize=10)

handles = [bar[0] for bar in bar_lists[0]]
fig.legend(handles, methods, loc='upper center',
           bbox_to_anchor=(0.5, 1.0),
           ncol=5, frameon=False, fontsize=10,
           columnspacing=0.8, handletextpad=0.4)

plt.tight_layout(pad=0.8, rect=[0, 0, 1, 0.9])
plt.subplots_adjust(hspace=0.6, wspace=0.3)
plt.savefig('2.pdf',format='pdf', dpi=400, transparent=True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(2, 3, figsize=(16, 8))
x_labels = ['1', '2', '3', '4']

# 1. WebQSP (row1 col1)
webqsp_total = [67.0, 70.3, 74.7, 75.0]
webqsp_filtered = [45.8, 57.0, 58.9, 60.6]
all_points = webqsp_total + webqsp_filtered
ymin, ymax = min(all_points), max(all_points)
padding = (ymax - ymin) * 0.08
ax1.plot(x_labels, webqsp_total, marker='o', color='#1f77b4', linewidth=4, markersize=12, alpha=0.7, label='#Total')
ax1.plot(x_labels, webqsp_filtered, marker='s', color='#ff7f0e', linewidth=4, markersize=12, alpha=0.7, label='#Filtered')
ax1.set_ylim(ymin - padding, ymax + padding)
ax1.set_title('WebQSP', fontsize=25)
ax1.tick_params(axis='both', which='major', labelsize=25)
ax1.set_xlabel('width', fontsize=25)
ax1.set_ylabel('Hits@1', fontsize=28)
for i, (x, y) in enumerate(zip(x_labels, webqsp_total)):
    ax1.annotate(f'{y:.1f}', (x, y), textcoords="offset points", xytext=(0, -25), ha='center', color='#1f77b4', fontsize=20)
for i, (x, y) in enumerate(zip(x_labels, webqsp_filtered)):
    ax1.annotate(f'{y:.1f}', (x, y), textcoords="offset points", xytext=(0, 5), ha='center', color='#ff7f0e', fontsize=20)

# 2. CWQ (row1 col2)
cwq_total = [51.6, 55.3, 60.0, 60.3]
cwq_filtered = [22.0, 33.0, 36.3, 37.2]
all_points = cwq_total + cwq_filtered
ymin, ymax = min(all_points), max(all_points)
padding = (ymax - ymin) * 0.08
ax2.plot(x_labels, cwq_total, marker='o', color='#1f77b4', linewidth=4, markersize=12, alpha=0.7, label='#Total')
ax2.plot(x_labels, cwq_filtered, marker='s', color='#ff7f0e', linewidth=4, markersize=12, alpha=0.7, label='#Filtered')
ax2.set_ylim(ymin - padding, ymax + padding)
ax2.set_title('CWQ', fontsize=25)
ax2.tick_params(axis='both', which='major', labelsize=25)
ax2.set_xlabel('width', fontsize=25)
for i, (x, y) in enumerate(zip(x_labels, cwq_total)):
    ax2.annotate(f'{y:.1f}', (x, y), textcoords="offset points", xytext=(0, -25), ha='center', color='#1f77b4', fontsize=20)
for i, (x, y) in enumerate(zip(x_labels, cwq_filtered)):
    ax2.annotate(f'{y:.1f}', (x, y), textcoords="offset points", xytext=(0, 5), ha='center', color='#ff7f0e', fontsize=20)

# 3. GrailQA (row1 col3)
grailqa_total = [72.1, 77.1, 78.7, 78.6]
grailqa_filtered = [63.3, 70.4, 71.8, 70.4]
all_points = grailqa_total + grailqa_filtered
ymin, ymax = min(all_points), max(all_points)
padding = (ymax - ymin) * 0.08
ax3.plot(x_labels, grailqa_total, marker='o', color='#1f77b4', linewidth=4, markersize=12, alpha=0.7, label='#Total')
ax3.plot(x_labels, grailqa_filtered, marker='s', color='#ff7f0e', linewidth=4, markersize=12, alpha=0.7, label='#Filtered')
ax3.set_ylim(ymin - padding, ymax + padding)
ax3.set_title('GrailQA', fontsize=25)
ax3.tick_params(axis='both', which='major', labelsize=25)
ax3.set_xlabel('width', fontsize=25)
for i, (x, y) in enumerate(zip(x_labels, grailqa_total)):
    ax3.annotate(f'{y:.1f}', (x, y), textcoords="offset points", xytext=(0, -25), ha='center', color='#1f77b4', fontsize=20)
for i, (x, y) in enumerate(zip(x_labels, grailqa_filtered)):
    ax3.annotate(f'{y:.1f}', (x, y), textcoords="offset points", xytext=(0, 5), ha='center', color='#ff7f0e', fontsize=20)

# 4. WebQSP (row2 col1)
webqsp_total = [72.8, 74.4, 74.7, 73.1]
webqsp_filtered = [58.5, 60.7, 58.9, 60.4]
all_points = webqsp_total + webqsp_filtered
ymin, ymax = min(all_points), max(all_points)
padding = (ymax - ymin) * 0.08
ax4.plot(x_labels, webqsp_total, marker='o', color='#1f77b4', linewidth=4, markersize=12, alpha=0.7, label='#Total')
ax4.plot(x_labels, webqsp_filtered, marker='s', color='#ff7f0e', linewidth=4, markersize=12, alpha=0.7, label='#Filtered')
ax4.set_ylim(ymin - padding, ymax + padding)
ax4.set_title('WebQSP', fontsize=25)
ax4.tick_params(axis='both', which='major', labelsize=25)
ax4.set_xlabel('depth', fontsize=25)
ax4.set_ylabel('Hits@1', fontsize=25)
for i, (x, y) in enumerate(zip(x_labels, webqsp_total)):
    ax4.annotate(f'{y:.1f}', (x, y), textcoords="offset points", xytext=(0, -25), ha='center', color='#1f77b4', fontsize=20)
for i, (x, y) in enumerate(zip(x_labels, webqsp_filtered)):
    ax4.annotate(f'{y:.1f}', (x, y), textcoords="offset points", xytext=(0, 5), ha='center', color='#ff7f0e', fontsize=20)

# 5. CWQ (row2 col2)
cwq_total = [39.7, 59.7, 60.0, 60.2]
cwq_filtered = [21.8, 37.0, 36.3, 35.2]
all_points = cwq_total + cwq_filtered
ymin, ymax = min(all_points), max(all_points)
padding = (ymax - ymin) * 0.08
ax5.plot(x_labels, cwq_total, marker='o', color='#1f77b4', linewidth=4, markersize=12, alpha=0.7, label='#Total')
ax5.plot(x_labels, cwq_filtered, marker='s', color='#ff7f0e', linewidth=4, markersize=12, alpha=0.7, label='#Filtered')
ax5.set_ylim(ymin - padding, ymax + padding)
ax5.set_title('CWQ', fontsize=25)
ax5.tick_params(axis='both', which='major', labelsize=25)
ax5.set_xlabel('depth', fontsize=25)
for i, (x, y) in enumerate(zip(x_labels, cwq_total)):
    ax5.annotate(f'{y:.1f}', (x, y), textcoords="offset points", xytext=(0, -25), ha='center', color='#1f77b4', fontsize=20)
for i, (x, y) in enumerate(zip(x_labels, cwq_filtered)):
    ax5.annotate(f'{y:.1f}', (x, y), textcoords="offset points", xytext=(0, 5), ha='center', color='#ff7f0e', fontsize=20)

# 6. GrailQA (row2 col3)
grailqa_total = [69.7, 78.2, 78.7, 77.1]
grailqa_filtered = [64.5, 72.1, 71.8, 70.3]
all_points = grailqa_total + grailqa_filtered
ymin, ymax = min(all_points), max(all_points)
padding = (ymax - ymin) * 0.08
ax6.plot(x_labels, grailqa_total, marker='o', color='#1f77b4', linewidth=4, markersize=12, alpha=0.7, label='#Total')
ax6.plot(x_labels, grailqa_filtered, marker='s', color='#ff7f0e', linewidth=4, markersize=12, alpha=0.7, label='#Filtered')
ax6.set_ylim(ymin - padding, ymax + padding)
ax6.set_title('GrailQA', fontsize=25)
ax6.tick_params(axis='both', which='major', labelsize=25)
ax6.set_xlabel('depth', fontsize=25)
for i, (x, y) in enumerate(zip(x_labels, grailqa_total)):
    if i != 0:
        ax6.annotate(f'{y:.1f}', (x, y), textcoords="offset points", xytext=(0, -25), ha='center', color='#1f77b4', fontsize=20)
    else:
        ax6.annotate(f'{y:.1f}', (x, y), textcoords="offset points", xytext=(10, -25), ha='center', color='#1f77b4', fontsize=20)
for i, (x, y) in enumerate(zip(x_labels, grailqa_filtered)):
    if i != 0:
        ax6.annotate(f'{y:.1f}', (x, y), textcoords="offset points", xytext=(0, 5), ha='center', color='#ff7f0e', fontsize=20)
    else:
        ax6.annotate(f'{y:.1f}', (x, y), textcoords="offset points", xytext=(10, 5), ha='center', color='#ff7f0e', fontsize=20)

for ax in [ax1]:
    ax.axhline(y=[10], linestyle='--', color='gray', linewidth=2, alpha=0.4)
    ax.axhline(y=[20], linestyle='--', color='gray', linewidth=2, alpha=0.4)
    ax.axhline(y=[30], linestyle='--', color='gray', linewidth=2, alpha=0.4)
    ax.axhline(y=[40], linestyle='--', color='gray', linewidth=2, alpha=0.4)
    ax.axhline(y=[50], linestyle='--', color='gray', linewidth=2, alpha=0.4)
    ax.axhline(y=[60], linestyle='--', color='gray', linewidth=2, alpha=0.4)
    ax.axhline(y=[70], linestyle='--', color='gray', linewidth=2, alpha=0.4)
for ax in [ax2]:
    ax.axhline(y=[10], linestyle='--', color='gray', linewidth=2, alpha=0.4)
    ax.axhline(y=[20], linestyle='--', color='gray', linewidth=2, alpha=0.4)
    ax.axhline(y=[30], linestyle='--', color='gray', linewidth=2, alpha=0.4)
    ax.axhline(y=[40], linestyle='--', color='gray', linewidth=2, alpha=0.4)
    ax.axhline(y=[50], linestyle='--', color='gray', linewidth=2, alpha=0.4)
    ax.axhline(y=[60], linestyle='--', color='gray', linewidth=2, alpha=0.4)
    ax.axhline(y=[70], linestyle='--', color='gray', linewidth=2, alpha=0.4)
for ax in [ax3]:
    ax.axhline(y=[65], linestyle='--', color='gray', linewidth=2, alpha=0.4)
    ax.axhline(y=[70], linestyle='--', color='gray', linewidth=2, alpha=0.4)
    ax.axhline(y=[75], linestyle='--', color='gray', linewidth=2, alpha=0.4)
    ax.axhline(y=[80], linestyle='--', color='gray', linewidth=2, alpha=0.4)
    ax.axhline(y=[50], linestyle='--', color='gray', linewidth=2, alpha=0.4)
    ax.axhline(y=[60], linestyle='--', color='gray', linewidth=2, alpha=0.4)
    ax.axhline(y=[70], linestyle='--', color='gray', linewidth=2, alpha=0.4)
for ax in [ax4]:
    ax.axhline(y=[65], linestyle='--', color='gray', linewidth=2, alpha=0.4)
    ax.axhline(y=[70], linestyle='--', color='gray', linewidth=2, alpha=0.4)
    ax.axhline(y=[75], linestyle='--', color='gray', linewidth=2, alpha=0.4)
    ax.axhline(y=[80], linestyle='--', color='gray', linewidth=2, alpha=0.4)
    ax.axhline(y=[50], linestyle='--', color='gray', linewidth=2, alpha=0.4)
    ax.axhline(y=[60], linestyle='--', color='gray', linewidth=2, alpha=0.4)
    ax.axhline(y=[70], linestyle='--', color='gray', linewidth=2, alpha=0.4)
for ax in [ax5]:
    ax.axhline(y=[10], linestyle='--', color='gray', linewidth=2, alpha=0.4)
    ax.axhline(y=[20], linestyle='--', color='gray', linewidth=2, alpha=0.4)
    ax.axhline(y=[30], linestyle='--', color='gray', linewidth=2, alpha=0.4)
    ax.axhline(y=[40], linestyle='--', color='gray', linewidth=2, alpha=0.4)
    ax.axhline(y=[50], linestyle='--', color='gray', linewidth=2, alpha=0.4)
    ax.axhline(y=[60], linestyle='--', color='gray', linewidth=2, alpha=0.4)
    ax.axhline(y=[70], linestyle='--', color='gray', linewidth=2, alpha=0.4)
for ax in [ax6]:
    ax.axhline(y=[65], linestyle='--', color='gray', linewidth=2, alpha=0.4)
    ax.axhline(y=[70], linestyle='--', color='gray', linewidth=2, alpha=0.4)
    ax.axhline(y=[75], linestyle='--', color='gray', linewidth=2, alpha=0.4)
    ax.axhline(y=[80], linestyle='--', color='gray', linewidth=2, alpha=0.4)
    ax.axhline(y=[50], linestyle='--', color='gray', linewidth=2, alpha=0.4)
    ax.axhline(y=[60], linestyle='--', color='gray', linewidth=2, alpha=0.4)
    ax.axhline(y=[70], linestyle='--', color='gray', linewidth=2, alpha=0.4)
# 添加全局图例
handles, labels = ax1.get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center', bbox_to_anchor=(0.5, 1.03), ncol=2, frameon=False, fontsize=25)
plt.subplots_adjust(wspace=0.2, hspace=0.6)
plt.savefig('3.pdf', format='pdf', bbox_inches='tight', dpi=400)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


data = {
    'Exposure Level': ['P-RAG', 'P-G', 'P-R', 'Private'],
    'WebQSP_Total_ARoG': [77.9, 77.9, 74.7, 74.7],
    'WebQSP_Filtered_ARoG': [59.3, 59.3, 58.9, 58.9],
    'WebQSP_Total_ARoG-R': [80.5, 75.5, 74.9, 70.6],
    'WebQSP_Filtered_ARoG-R': [56.1, 46.9, 58.3, 43.4],
    'WebQSP_Total_ToG': [78.7, 78.5, 65.3, 64.9],
    'WebQSP_Filtered_ToG': [42.2, 41.3, 8.8, 8.2],

    'CWQ_Total_ARoG': [64, 64, 60, 60],
    'CWQ_Filtered_ARoG': [41.2, 41.2, 36.3, 36.3],
    'CWQ_Total_ARoG-R': [63.1, 58.3, 54.3, 56.9],
    'CWQ_Filtered_ARoG-R': [32.5, 22.9, 29.1, 20.3],
    'CWQ_Total_ToG': [61.1, 60.9, 52.5, 54.1],
    'CWQ_Filtered_ToG': [19.8, 19.8, 4.2, 4.9],

    'GrailQA_Total_ARoG': [79.4, 79.4, 78.7, 78.7],
    'GrailQA_Filtered_ARoG': [72.6, 72.6, 71.8, 71.8],
    'GrailQA_Total_ARoG-R': [75.8, 75.6, 74.9, 74.6],
    'GrailQA_Filtered_ARoG-R': [66.6, 67.6, 67.6, 65.2],
    'GrailQA_Total_ToG': [72.8, 74.5, 38.2, 38.9],
    'GrailQA_Filtered_ToG': [61.9, 63.5, 17.3, 17]

}


df = pd.DataFrame(data)


fig, axes = plt.subplots(1, 3, figsize=(16, 6))

datasets = ['WebQSP', 'CWQ', 'GrailQA']
methods = ['ARoG', 'ARoG-R', 'ToG']

lines, labels = [], []

for i, dataset in enumerate(datasets):
    for xi in range(len(df['Exposure Level'])):
        axes[i].axvline(x=xi, color='gray', linestyle='dashed', alpha=0.5, linewidth=2)

    for method in methods:
        line, = axes[i].plot(df['Exposure Level'],
                             df[f'{dataset}_Total_{method}'],
                             marker='o',
                             alpha=0.7,
                             linewidth=4,
                             markersize=12,
                             label=f'{method} (Total)')
        if i==0:
            lines.append(line)
            labels.append(f'{method} (Total)')

        line, = axes[i].plot(df['Exposure Level'],
                             df[f'{dataset}_Filtered_{method}'],
                             marker="^",
                             alpha=0.7,
                             linewidth=4,
                             markersize=12,
                             linestyle='--',
                             label=f'{method} (Filtered)')
        if i==0:
            lines.append(line)
            labels.append(f'{method} (Filtered)')
    
    axes[i].set_title(f'{dataset}', fontsize=25)
    axes[i].tick_params(axis='both', which='major', labelsize=30)
    if i==0:
        axes[i].set_ylabel('Hits@1', fontsize=25)
    



labels=list(dict.fromkeys(labels))
fig.legend(lines, labels, loc='upper center', ncol=3, frameon=False,fontsize=25)

plt.tight_layout(rect=[0, 0, 1, 0.76])
plt.savefig('4.pdf', format='pdf', bbox_inches='tight', dpi=400)
plt.show()
